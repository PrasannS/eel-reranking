# %%
import flatten_lattice as fl
import torch
from bert_models import LinearPOSBertV1
from encoding_utils import *
from transformers import AutoTokenizer
import pickle
from mask_utils import *
import json
import os
import numpy as np
from distill_comet import XLMCometEmbeds, XLMCometRegressor

device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
xlm_tok = fl.bert_tok
# Out:
# 2022-10-10 07:08:25.462567: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-10 07:08:25.462588: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#V12 first attempt with inputs prepended
#V14 final pipeline first attempt
VNUM = 14
MOD_NAME = 'bertonewayv1.pth'

# specifies files for pre-loading
LOADED = {
    'amasks': 'attmasksallv'+str(VNUM)+'.pt',
    'tmaps': 'tmapsmaskedv'+str(VNUM)+'/'
}

# %%
def prepend_input(pgraph, inp):
    
    inptoks = xlm_tok(inp).input_ids
    # add in the <s> token
    # we don't need the </s> token by how the mask works
    inptoks.append(0)
    posadd = len(inptoks)
    inpflat = []
    ind = 0
    for i in range(len(inptoks)):
        nl = []
        inp = inptoks[i]
        if i<(len(inptoks)-1):
            nl.append(str(inptoks[i+1])+" "+str(ind+1))
        inpflat.append({
            'token_idx':inp, 
            'pos':ind,
            'id': str(inp)+" "+str(ind),
            'nexts':nl,
            'score':0,
        })
        ind+=1
    inpflat[-1]['nexts'].append(pgraph[0]['id'].split()[0]+" "+str(posadd))
    
    inpflat.extend(pgraph)
    for i in range(posadd, len(inpflat)):
        extok = inpflat[i]
        extok['pos']+=posadd
        extok['id']= str(extok['token_idx'])+" "+str(extok['pos'])
        for j in range(len(extok['nexts'])):
            newpos = int(extok['nexts'][j].split()[1])+posadd
            extok['nexts'][j] = extok['nexts'][j].split()[0]+" "+str(newpos)
    return inpflat, posadd

# %%
STOPS = -1

# Get examples (just use the normal lattice examples ig?)
processedgraphs, inps, refs = fl.get_processed_graph_data(fl.frenbase, -1, STOPS)

# get exploded candidates to generate gold labels
resarrs = [fl.get_cover_paths(p)[0] for p in processedgraphs]

# extra step for greedy 
if STOPS==1:
    processedgraphs = filter_greedy(processedgraphs)
    

# ensure no empty examples
clean_empty(resarrs, processedgraphs)

ppinput = [prepend_input(processedgraphs[i], inps[i]) for i in range(len(processedgraphs))]
processedgraphs = [p[0] for p in ppinput]
posadds = [p[1] for p in ppinput]

# %%
def causal_mask (pgraph, padd):
    start = connect_mat(processedgraphs[0])
    start[:, :padd] = 1
    start[:padd, padd:] = 0 
    start[padd:, padd:] = torch.tril(start[padd:, padd:])
    return start

def get_allamasks():
    attmasks = []
    for i in range(len(posadds)):
        if i%10==0:
            print(i)
        attmasks.append(causal_mask(processedgraphs[i], posadds[i]-1))
    return attmasks

# %%
processedgraphs[0]
# Out:
# [{'token_idx': 0, 'pos': 0, 'id': '0 0', 'nexts': ['636 1'], 'score': 0},
#  {'token_idx': 636, 'pos': 1, 'id': '636 1', 'nexts': ['77057 2'], 'score': 0},
#  {'token_idx': 77057,
#   'pos': 2,
#   'id': '77057 2',
#   'nexts': ['100527 3'],
#   'score': 0},
#  {'token_idx': 100527,
#   'pos': 3,
#   'id': '100527 3',
#   'nexts': ['171318 4'],
#   'score': 0},
#  {'token_idx': 171318,
#   'pos': 4,
#   'id': '171318 4',
#   'nexts': ['135328 5'],
#   'score': 0},
#  {'token_idx': 135328,
#   'pos': 5,
#   'id': '135328 5',
#   'nexts': ['78189 6'],
#   'score': 0},
#  {'token_idx': 78189,
#   'pos': 6,
#   'id': '78189 6',
#   'nexts': ['106 7'],
#   'score': 0},
#  {'token_idx': 106, 'pos': 7, 'id': '106 7', 'nexts': ['56 8'], 'score': 0},
#  {'token_idx': 56, 'pos': 8, 'id': '56 8', 'nexts': ['15430 9'], 'score': 0},
#  {'token_idx': 15430,
#   'pos': 9,
#   'id': '15430 9',
#   'nexts': ['1210 10'],
#   'score': 0},
#  {'token_idx': 1210,
#   'pos': 10,
#   'id': '1210 10',
#   'nexts': ['95 11'],
#   'score': 0},
#  {'token_idx': 95, 'pos': 11, 'id': '95 11', 'nexts': ['9882 12'], 'score': 0},
#  {'token_idx': 9882,
#   'pos': 12,
#   'id': '9882 12',
#   'nexts': ['57112 13'],
#   'score': 0},
#  {'token_idx': 57112,
#   'pos': 13,
#   'id': '57112 13',
#   'nexts': ['193 14'],
#   'score': 0},
#  {'token_idx': 193, 'pos': 14, 'id': '193 14', 'nexts': ['11 15'], 'score': 0},
#  {'token_idx': 11,
#   'pos': 15,
#   'id': '11 15',
#   'nexts': ['27172 16'],
#   'score': 0},
#  {'token_idx': 27172,
#   'pos': 16,
#   'id': '27172 16',
#   'nexts': ['438 17'],
#   'score': 0},
#  {'token_idx': 438,
#   'pos': 17,
#   'id': '438 17',
#   'nexts': ['1162 18'],
#   'score': 0},
#  {'token_idx': 1162,
#   'pos': 18,
#   'id': '1162 18',
#   'nexts': ['884 19'],
#   'score': 0},
#  {'token_idx': 884,
#   'pos': 19,
#   'id': '884 19',
#   'nexts': ['69778 20'],
#   'score': 0},
#  {'token_idx': 69778,
#   'pos': 20,
#   'id': '69778 20',
#   'nexts': ['14 21'],
#   'score': 0},
#  {'token_idx': 14, 'pos': 21, 'id': '14 21', 'nexts': ['4 22'], 'score': 0},
#  {'token_idx': 4, 'pos': 22, 'id': '4 22', 'nexts': ['22 23'], 'score': 0},
#  {'token_idx': 22,
#   'pos': 23,
#   'id': '22 23',
#   'nexts': ['69904 24'],
#   'score': 0},
#  {'token_idx': 69904,
#   'pos': 24,
#   'id': '69904 24',
#   'nexts': ['67 25'],
#   'score': 0},
#  {'token_idx': 67, 'pos': 25, 'id': '67 25', 'nexts': ['104 26'], 'score': 0},
#  {'token_idx': 104, 'pos': 26, 'id': '104 26', 'nexts': ['25 27'], 'score': 0},
#  {'token_idx': 25,
#   'pos': 27,
#   'id': '25 27',
#   'nexts': ['41567 28'],
#   'score': 0},
#  {'token_idx': 41567,
#   'pos': 28,
#   'id': '41567 28',
#   'nexts': ['224 29'],
#   'score': 0},
#  {'token_idx': 224,
#   'pos': 29,
#   'id': '224 29',
#   'nexts': ['166514 30'],
#   'score': 0},
#  {'token_idx': 166514,
#   'pos': 30,
#   'id': '166514 30',
#   'nexts': ['9 31'],
#   'score': 0},
#  {'token_idx': 9, 'pos': 31, 'id': '9 31', 'nexts': ['103806 32'], 'score': 0},
#  {'token_idx': 103806,
#   'pos': 32,
#   'id': '103806 32',
#   'nexts': ['578 33'],
#   'score': 0},
#  {'token_idx': 578,
#   'pos': 33,
#   'id': '578 33',
#   'nexts': ['108821 34'],
#   'score': 0},
#  {'token_idx': 108821,
#   'pos': 34,
#   'id': '108821 34',
#   'nexts': ['42 35'],
#   'score': 0},
#  {'token_idx': 42,
#   'pos': 35,
#   'id': '42 35',
#   'nexts': ['13993 36'],
#   'score': 0},
#  {'token_idx': 13993,
#   'pos': 36,
#   'id': '13993 36',
#   'nexts': ['21 37'],
#   'score': 0},
#  {'token_idx': 21, 'pos': 37, 'id': '21 37', 'nexts': ['1001 38'], 'score': 0},
#  {'token_idx': 1001,
#   'pos': 38,
#   'id': '1001 38',
#   'nexts': ['11966 39'],
#   'score': 0},
#  {'token_idx': 11966,
#   'pos': 39,
#   'id': '11966 39',
#   'nexts': ['307 40'],
#   'score': 0},
#  {'token_idx': 307,
#   'pos': 40,
#   'id': '307 40',
#   'nexts': ['6261 41'],
#   'score': 0},
#  {'token_idx': 6261,
#   'pos': 41,
#   'id': '6261 41',
#   'nexts': ['8 42'],
#   'score': 0},
#  {'token_idx': 8, 'pos': 42, 'id': '8 42', 'nexts': ['95319 43'], 'score': 0},
#  {'token_idx': 95319,
#   'pos': 43,
#   'id': '95319 43',
#   'nexts': ['13106 44'],
#   'score': 0},
#  {'token_idx': 13106,
#   'pos': 44,
#   'id': '13106 44',
#   'nexts': ['84750 45'],
#   'score': 0},
#  {'token_idx': 84750,
#   'pos': 45,
#   'id': '84750 45',
#   'nexts': ['7210 46'],
#   'score': 0},
#  {'token_idx': 7210,
#   'pos': 46,
#   'id': '7210 46',
#   'nexts': ['5 47'],
#   'score': 0},
#  {'token_idx': 5, 'pos': 47, 'id': '5 47', 'nexts': ['2 48'], 'score': 0},
#  {'token_idx': 2, 'pos': 48, 'id': '2 48', 'nexts': ['0 49'], 'score': 0},
#  {'token_idx': 0, 'pos': 49, 'id': '0 49', 'nexts': ['581 50'], 'score': 0},
#  {'token_idx': 581,
#   'pos': 50,
#   'id': '581 50',
#   'nexts': ['7082 51'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 51,
#   'id': '7082 51',
#   'nexts': ['34202 52'],
#   'score': 0},
#  {'token_idx': 34202,
#   'pos': 52,
#   'id': '34202 52',
#   'nexts': ['509 53'],
#   'score': 0},
#  {'token_idx': 509, 'pos': 53, 'id': '509 53', 'nexts': ['47 54'], 'score': 0},
#  {'token_idx': 47,
#   'pos': 54,
#   'id': '47 54',
#   'nexts': ['53299 55'],
#   'score': 0},
#  {'token_idx': 53299,
#   'pos': 55,
#   'id': '53299 55',
#   'nexts': ['69496 56'],
#   'score': 0},
#  {'token_idx': 69496,
#   'pos': 56,
#   'id': '69496 56',
#   'nexts': ['14 57'],
#   'score': 0},
#  {'token_idx': 14,
#   'pos': 57,
#   'id': '14 57',
#   'nexts': ['56195 58'],
#   'score': 0},
#  {'token_idx': 56195,
#   'pos': 58,
#   'id': '56195 58',
#   'nexts': ['33744 59'],
#   'score': 0},
#  {'token_idx': 33744,
#   'pos': 59,
#   'id': '33744 59',
#   'nexts': ['438 60'],
#   'score': 0},
#  {'token_idx': 438,
#   'pos': 60,
#   'id': '438 60',
#   'nexts': ['1162 61'],
#   'score': 0},
#  {'token_idx': 1162,
#   'pos': 61,
#   'id': '1162 61',
#   'nexts': ['884 62'],
#   'score': 0},
#  {'token_idx': 884,
#   'pos': 62,
#   'id': '884 62',
#   'nexts': ['69778 63'],
#   'score': 0},
#  {'token_idx': 69778,
#   'pos': 63,
#   'id': '69778 63',
#   'nexts': ['14 64'],
#   'score': 0},
#  {'token_idx': 14,
#   'pos': 64,
#   'id': '14 64',
#   'nexts': ['2 65', '41626 65', '98 65'],
#   'score': 0},
#  {'token_idx': 41626,
#   'pos': 65,
#   'id': '41626 65',
#   'nexts': ['4 66'],
#   'score': 0},
#  {'token_idx': 4, 'pos': 66, 'id': '4 66', 'nexts': ['7582 67'], 'score': 0},
#  {'token_idx': 7582,
#   'pos': 67,
#   'id': '7582 67',
#   'nexts': ['106 68'],
#   'score': 0},
#  {'token_idx': 106, 'pos': 68, 'id': '106 68', 'nexts': ['4 69'], 'score': 0},
#  {'token_idx': 4,
#   'pos': 69,
#   'id': '4 69',
#   'nexts': ['2 70', '1210 70', '24159 70'],
#   'score': 0},
#  {'token_idx': 1210,
#   'pos': 70,
#   'id': '1210 70',
#   'nexts': ['23 71'],
#   'score': 0},
#  {'token_idx': 23, 'pos': 71, 'id': '23 71', 'nexts': ['142 72'], 'score': 0},
#  {'token_idx': 142,
#   'pos': 72,
#   'id': '142 72',
#   'nexts': ['71834 73'],
#   'score': 0},
#  {'token_idx': 71834,
#   'pos': 73,
#   'id': '71834 73',
#   'nexts': ['47 74'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 74, 'id': '47 74', 'nexts': ['40 75'], 'score': 0},
#  {'token_idx': 40, 'pos': 75, 'id': '40 75', 'nexts': ['343 76'], 'score': 0},
#  {'token_idx': 343,
#   'pos': 76,
#   'id': '343 76',
#   'nexts': ['7082 77'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 77,
#   'id': '7082 77',
#   'nexts': ['127557 78'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 78,
#   'id': '127557 78',
#   'nexts': ['23 79'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 79,
#   'id': '23 79',
#   'nexts': ['181952 80'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 80,
#   'id': '181952 80',
#   'nexts': ['70 81'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 81,
#   'id': '70 81',
#   'nexts': ['130481 82'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 82,
#   'id': '130481 82',
#   'nexts': ['259 83'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 83,
#   'id': '259 83',
#   'nexts': ['272 84'],
#   'score': 0},
#  {'token_idx': 272,
#   'pos': 84,
#   'id': '272 84',
#   'nexts': ['111 85'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 85,
#   'id': '111 85',
#   'nexts': ['95319 86'],
#   'score': 0},
#  {'token_idx': 95319,
#   'pos': 86,
#   'id': '95319 86',
#   'nexts': ['23 87'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 87,
#   'id': '23 87',
#   'nexts': ['43606 88'],
#   'score': 0},
#  {'token_idx': 43606,
#   'pos': 88,
#   'id': '43606 88',
#   'nexts': ['5369 89'],
#   'score': 0},
#  {'token_idx': 5369,
#   'pos': 89,
#   'id': '5369 89',
#   'nexts': ['5 90'],
#   'score': 0},
#  {'token_idx': 5, 'pos': 90, 'id': '5 90', 'nexts': ['2 91'], 'score': 0},
#  {'token_idx': 24159,
#   'pos': 70,
#   'id': '24159 70',
#   'nexts': ['23 71'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 71,
#   'id': '23 71',
#   'nexts': ['33938 72'],
#   'score': 0},
#  {'token_idx': 33938,
#   'pos': 72,
#   'id': '33938 72',
#   'nexts': ['111 73'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 73,
#   'id': '111 73',
#   'nexts': ['7082 74'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 74,
#   'id': '7082 74',
#   'nexts': ['127557 75'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 75,
#   'id': '127557 75',
#   'nexts': ['47 76'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 76,
#   'id': '47 76',
#   'nexts': ['78431 77'],
#   'score': 0},
#  {'token_idx': 78431,
#   'pos': 77,
#   'id': '78431 77',
#   'nexts': ['70 78'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 78,
#   'id': '70 78',
#   'nexts': ['130481 79'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 79,
#   'id': '130481 79',
#   'nexts': ['259 80'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 80,
#   'id': '259 80',
#   'nexts': ['272 81'],
#   'score': 0},
#  {'token_idx': 272,
#   'pos': 81,
#   'id': '272 81',
#   'nexts': ['111 82'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 82,
#   'id': '111 82',
#   'nexts': ['95319 83'],
#   'score': 0},
#  {'token_idx': 95319,
#   'pos': 83,
#   'id': '95319 83',
#   'nexts': ['23 84'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 84,
#   'id': '23 84',
#   'nexts': ['43606 85'],
#   'score': 0},
#  {'token_idx': 43606,
#   'pos': 85,
#   'id': '43606 85',
#   'nexts': ['5369 86'],
#   'score': 0},
#  {'token_idx': 5369,
#   'pos': 86,
#   'id': '5369 86',
#   'nexts': ['5 87'],
#   'score': 0},
#  {'token_idx': 5, 'pos': 87, 'id': '5 87', 'nexts': ['2 88'], 'score': 0},
#  {'token_idx': 98,
#   'pos': 65,
#   'id': '98 65',
#   'nexts': ['41626 66'],
#   'score': 0},
#  {'token_idx': 41626,
#   'pos': 66,
#   'id': '41626 66',
#   'nexts': ['2 67', '106 67', '6 67'],
#   'score': 0},
#  {'token_idx': 106,
#   'pos': 67,
#   'id': '106 67',
#   'nexts': ['7582 68'],
#   'score': 0},
#  {'token_idx': 7582,
#   'pos': 68,
#   'id': '7582 68',
#   'nexts': ['2 69', '1210 69', '24159 69'],
#   'score': 0},
#  {'token_idx': 1210,
#   'pos': 69,
#   'id': '1210 69',
#   'nexts': ['23 70'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 70,
#   'id': '23 70',
#   'nexts': ['2 71', '33938 71', '142 71'],
#   'score': 0},
#  {'token_idx': 33938,
#   'pos': 71,
#   'id': '33938 71',
#   'nexts': ['111 72'],
#   'score': 0},
#  {'token_idx': 111, 'pos': 72, 'id': '111 72', 'nexts': ['2 73'], 'score': 0},
#  {'token_idx': 142, 'pos': 71, 'id': '142 71', 'nexts': ['2 72'], 'score': 0},
#  {'token_idx': 24159,
#   'pos': 69,
#   'id': '24159 69',
#   'nexts': ['2 70', '191618 70', '23 70'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 70,
#   'id': '191618 70',
#   'nexts': ['7082 71'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 71,
#   'id': '7082 71',
#   'nexts': ['127557 72'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 72,
#   'id': '127557 72',
#   'nexts': ['23 73'],
#   'score': 0},
#  {'token_idx': 23, 'pos': 73, 'id': '23 73', 'nexts': ['2 74'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 70,
#   'id': '23 70',
#   'nexts': ['2 71', '10 71', '142 71', '33938 71'],
#   'score': 0},
#  {'token_idx': 10,
#   'pos': 71,
#   'id': '10 71',
#   'nexts': ['45880 72'],
#   'score': 0},
#  {'token_idx': 45880,
#   'pos': 72,
#   'id': '45880 72',
#   'nexts': ['47 73'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 73, 'id': '47 73', 'nexts': ['4358 74'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 74,
#   'id': '4358 74',
#   'nexts': ['70 75'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 75,
#   'id': '70 75',
#   'nexts': ['14098 76'],
#   'score': 0},
#  {'token_idx': 14098,
#   'pos': 76,
#   'id': '14098 76',
#   'nexts': ['46684 77'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 77,
#   'id': '46684 77',
#   'nexts': ['78431 78'],
#   'score': 0},
#  {'token_idx': 78431,
#   'pos': 78,
#   'id': '78431 78',
#   'nexts': ['70 79'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 79,
#   'id': '70 79',
#   'nexts': ['130481 80'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 80,
#   'id': '130481 80',
#   'nexts': ['2 81'],
#   'score': 0},
#  {'token_idx': 142,
#   'pos': 71,
#   'id': '142 71',
#   'nexts': ['71834 72'],
#   'score': 0},
#  {'token_idx': 71834,
#   'pos': 72,
#   'id': '71834 72',
#   'nexts': ['47 73'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 73, 'id': '47 73', 'nexts': ['40 74'], 'score': 0},
#  {'token_idx': 40, 'pos': 74, 'id': '40 74', 'nexts': ['343 75'], 'score': 0},
#  {'token_idx': 343,
#   'pos': 75,
#   'id': '343 75',
#   'nexts': ['7082 76'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 76,
#   'id': '7082 76',
#   'nexts': ['127557 77'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 77,
#   'id': '127557 77',
#   'nexts': ['23 78'],
#   'score': 0},
#  {'token_idx': 23, 'pos': 78, 'id': '23 78', 'nexts': ['2 79'], 'score': 0},
#  {'token_idx': 33938,
#   'pos': 71,
#   'id': '33938 71',
#   'nexts': ['2 72'],
#   'score': 0},
#  {'token_idx': 6, 'pos': 67, 'id': '6 67', 'nexts': ['4 68'], 'score': 0},
#  {'token_idx': 4,
#   'pos': 68,
#   'id': '4 68',
#   'nexts': ['2 69', '106 68', '7582 68'],
#   'score': 0},
#  {'token_idx': 106,
#   'pos': 68,
#   'id': '106 68',
#   'nexts': ['7582 69'],
#   'score': 0},
#  {'token_idx': 7582,
#   'pos': 69,
#   'id': '7582 69',
#   'nexts': ['2 70', '1210 70', '24159 70'],
#   'score': 0},
#  {'token_idx': 1210,
#   'pos': 70,
#   'id': '1210 70',
#   'nexts': ['2 71'],
#   'score': 0},
#  {'token_idx': 24159,
#   'pos': 70,
#   'id': '24159 70',
#   'nexts': ['2 71', '191618 71'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 71,
#   'id': '191618 71',
#   'nexts': ['2 72'],
#   'score': 0},
#  {'token_idx': 7582,
#   'pos': 68,
#   'id': '7582 68',
#   'nexts': ['106 69'],
#   'score': 0},
#  {'token_idx': 106,
#   'pos': 69,
#   'id': '106 69',
#   'nexts': ['2 70', '6138 70', '6 70'],
#   'score': 0},
#  {'token_idx': 6138,
#   'pos': 70,
#   'id': '6138 70',
#   'nexts': ['2 71', '24159 71', '6 71'],
#   'score': 0},
#  {'token_idx': 24159,
#   'pos': 71,
#   'id': '24159 71',
#   'nexts': ['23 72'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 72,
#   'id': '23 72',
#   'nexts': ['33938 73'],
#   'score': 0},
#  {'token_idx': 33938,
#   'pos': 73,
#   'id': '33938 73',
#   'nexts': ['2 74'],
#   'score': 0},
#  {'token_idx': 6, 'pos': 71, 'id': '6 71', 'nexts': ['4 72'], 'score': 0},
#  {'token_idx': 4,
#   'pos': 72,
#   'id': '4 72',
#   'nexts': ['2 73', '23 72', '1210 72', '24159 72'],
#   'score': 0},
#  {'token_idx': 23, 'pos': 72, 'id': '23 72', 'nexts': ['142 73'], 'score': 0},
#  {'token_idx': 142,
#   'pos': 73,
#   'id': '142 73',
#   'nexts': ['71834 74'],
#   'score': 0},
#  {'token_idx': 71834,
#   'pos': 74,
#   'id': '71834 74',
#   'nexts': ['2 75'],
#   'score': 0},
#  {'token_idx': 1210,
#   'pos': 72,
#   'id': '1210 72',
#   'nexts': ['23 73'],
#   'score': 0},
#  {'token_idx': 23, 'pos': 73, 'id': '23 73', 'nexts': ['142 74'], 'score': 0},
#  {'token_idx': 142,
#   'pos': 74,
#   'id': '142 74',
#   'nexts': ['2 75', '81887 75', '71834 75'],
#   'score': 0},
#  {'token_idx': 81887,
#   'pos': 75,
#   'id': '81887 75',
#   'nexts': ['47 76'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 76, 'id': '47 76', 'nexts': ['40 77'], 'score': 0},
#  {'token_idx': 40, 'pos': 77, 'id': '40 77', 'nexts': ['343 78'], 'score': 0},
#  {'token_idx': 343,
#   'pos': 78,
#   'id': '343 78',
#   'nexts': ['7082 79'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 79,
#   'id': '7082 79',
#   'nexts': ['127557 80'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 80,
#   'id': '127557 80',
#   'nexts': ['23 81'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 81,
#   'id': '23 81',
#   'nexts': ['181952 82'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 82,
#   'id': '181952 82',
#   'nexts': ['70 83'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 83,
#   'id': '70 83',
#   'nexts': ['130481 84'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 84,
#   'id': '130481 84',
#   'nexts': ['259 85'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 85,
#   'id': '259 85',
#   'nexts': ['272 86'],
#   'score': 0},
#  {'token_idx': 272,
#   'pos': 86,
#   'id': '272 86',
#   'nexts': ['111 87'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 87,
#   'id': '111 87',
#   'nexts': ['95319 88'],
#   'score': 0},
#  {'token_idx': 95319,
#   'pos': 88,
#   'id': '95319 88',
#   'nexts': ['23 89'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 89,
#   'id': '23 89',
#   'nexts': ['43606 90'],
#   'score': 0},
#  {'token_idx': 43606,
#   'pos': 90,
#   'id': '43606 90',
#   'nexts': ['5369 91'],
#   'score': 0},
#  {'token_idx': 5369,
#   'pos': 91,
#   'id': '5369 91',
#   'nexts': ['5 92'],
#   'score': 0},
#  {'token_idx': 5, 'pos': 92, 'id': '5 92', 'nexts': ['2 93'], 'score': 0},
#  {'token_idx': 71834,
#   'pos': 75,
#   'id': '71834 75',
#   'nexts': ['47 76'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 76,
#   'id': '47 76',
#   'nexts': ['2 77', '7413 77', '4358 77', '40 77'],
#   'score': 0},
#  {'token_idx': 7413,
#   'pos': 77,
#   'id': '7413 77',
#   'nexts': ['7082 78'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 78,
#   'id': '7082 78',
#   'nexts': ['8060 79'],
#   'score': 0},
#  {'token_idx': 8060,
#   'pos': 79,
#   'id': '8060 79',
#   'nexts': ['47 80'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 80,
#   'id': '47 80',
#   'nexts': ['78431 81'],
#   'score': 0},
#  {'token_idx': 78431,
#   'pos': 81,
#   'id': '78431 81',
#   'nexts': ['70 82'],
#   'score': 0},
#  {'token_idx': 70, 'pos': 82, 'id': '70 82', 'nexts': ['2 83'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 77,
#   'id': '4358 77',
#   'nexts': ['70 78'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 78,
#   'id': '70 78',
#   'nexts': ['14098 79'],
#   'score': 0},
#  {'token_idx': 14098,
#   'pos': 79,
#   'id': '14098 79',
#   'nexts': ['46684 80'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 80,
#   'id': '46684 80',
#   'nexts': ['2 81', '30641 81', '78431 81'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 81,
#   'id': '30641 81',
#   'nexts': ['70 82'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 82,
#   'id': '70 82',
#   'nexts': ['130481 83'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 83,
#   'id': '130481 83',
#   'nexts': ['259 84'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 84,
#   'id': '259 84',
#   'nexts': ['272 85'],
#   'score': 0},
#  {'token_idx': 272, 'pos': 85, 'id': '272 85', 'nexts': ['2 86'], 'score': 0},
#  {'token_idx': 70,
#   'pos': 82,
#   'id': '70 82',
#   'nexts': ['2 83', '129058 83', '37515 83', '130481 83'],
#   'score': 0},
#  {'token_idx': 129058,
#   'pos': 83,
#   'id': '129058 83',
#   'nexts': ['259 84'],
#   'score': 0},
#  {'token_idx': 272,
#   'pos': 85,
#   'id': '272 85',
#   'nexts': ['111 86'],
#   'score': 0},
#  {'token_idx': 111, 'pos': 86, 'id': '111 86', 'nexts': ['2 87'], 'score': 0},
#  {'token_idx': 37515,
#   'pos': 83,
#   'id': '37515 83',
#   'nexts': ['525 84'],
#   'score': 0},
#  {'token_idx': 525,
#   'pos': 84,
#   'id': '525 84',
#   'nexts': ['259 85'],
#   'score': 0},
#  {'token_idx': 111, 'pos': 87, 'id': '111 87', 'nexts': ['2 88'], 'score': 0},
#  {'token_idx': 130481,
#   'pos': 83,
#   'id': '130481 83',
#   'nexts': ['2 84'],
#   'score': 0},
#  {'token_idx': 343, 'pos': 78, 'id': '343 78', 'nexts': ['2 79'], 'score': 0},
#  {'token_idx': 24159,
#   'pos': 72,
#   'id': '24159 72',
#   'nexts': ['2 73', '191618 73', '23 73'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 73,
#   'id': '191618 73',
#   'nexts': ['7082 74'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 74,
#   'id': '7082 74',
#   'nexts': ['2 75', '36442 75', '8060 75', '4358 75', '127557 75'],
#   'score': 0},
#  {'token_idx': 36442,
#   'pos': 75,
#   'id': '36442 75',
#   'nexts': ['47 76'],
#   'score': 0},
#  {'token_idx': 70, 'pos': 78, 'id': '70 78', 'nexts': ['2 79'], 'score': 0},
#  {'token_idx': 8060,
#   'pos': 75,
#   'id': '8060 75',
#   'nexts': ['2 76', '47 76', '23 76'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 76,
#   'id': '23 76',
#   'nexts': ['181952 77'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 77,
#   'id': '181952 77',
#   'nexts': ['70 78'],
#   'score': 0},
#  {'token_idx': 4358,
#   'pos': 75,
#   'id': '4358 75',
#   'nexts': ['23 76'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 75,
#   'id': '127557 75',
#   'nexts': ['2 76', '47 76', '23 76'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 76, 'id': '47 76', 'nexts': ['2 77'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 76,
#   'id': '23 76',
#   'nexts': ['2 77', '30641 77', '181952 77'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 77,
#   'id': '30641 77',
#   'nexts': ['214 78'],
#   'score': 0},
#  {'token_idx': 214, 'pos': 78, 'id': '214 78', 'nexts': ['70 79'], 'score': 0},
#  {'token_idx': 130481,
#   'pos': 80,
#   'id': '130481 80',
#   'nexts': ['259 81'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 81,
#   'id': '259 81',
#   'nexts': ['272 82'],
#   'score': 0},
#  {'token_idx': 272, 'pos': 82, 'id': '272 82', 'nexts': ['2 83'], 'score': 0},
#  {'token_idx': 272, 'pos': 81, 'id': '272 81', 'nexts': ['2 82'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 73,
#   'id': '23 73',
#   'nexts': ['2 74', '142 74', '33938 74'],
#   'score': 0},
#  {'token_idx': 142,
#   'pos': 74,
#   'id': '142 74',
#   'nexts': ['71834 75'],
#   'score': 0},
#  {'token_idx': 71834,
#   'pos': 75,
#   'id': '71834 75',
#   'nexts': ['2 76'],
#   'score': 0},
#  {'token_idx': 33938,
#   'pos': 74,
#   'id': '33938 74',
#   'nexts': ['111 75'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 75,
#   'id': '111 75',
#   'nexts': ['2 76', '127557 76', '14098 76', '4358 76', '345 76', '7082 76'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 76,
#   'id': '127557 76',
#   'nexts': ['1295 77'],
#   'score': 0},
#  {'token_idx': 1295,
#   'pos': 77,
#   'id': '1295 77',
#   'nexts': ['70 78'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 80,
#   'id': '46684 80',
#   'nexts': ['2 81', '47 81', '23 81'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 81,
#   'id': '47 81',
#   'nexts': ['2 82', '30641 82', '78431 82'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 82,
#   'id': '30641 82',
#   'nexts': ['70 83'],
#   'score': 0},
#  {'token_idx': 272, 'pos': 86, 'id': '272 86', 'nexts': ['2 87'], 'score': 0},
#  {'token_idx': 78431,
#   'pos': 82,
#   'id': '78431 82',
#   'nexts': ['70 83'],
#   'score': 0},
#  {'token_idx': 70, 'pos': 83, 'id': '70 83', 'nexts': ['2 84'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 81,
#   'id': '23 81',
#   'nexts': ['2 82', '30641 82', '181952 82'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 82,
#   'id': '30641 82',
#   'nexts': ['214 83'],
#   'score': 0},
#  {'token_idx': 214, 'pos': 83, 'id': '214 83', 'nexts': ['70 84'], 'score': 0},
#  {'token_idx': 70,
#   'pos': 84,
#   'id': '70 84',
#   'nexts': ['130481 85'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 85,
#   'id': '130481 85',
#   'nexts': ['259 86'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 86,
#   'id': '259 86',
#   'nexts': ['272 87'],
#   'score': 0},
#  {'token_idx': 272, 'pos': 87, 'id': '272 87', 'nexts': ['2 88'], 'score': 0},
#  {'token_idx': 46684,
#   'pos': 77,
#   'id': '46684 77',
#   'nexts': ['2 78', '36442 78', '127557 78'],
#   'score': 0},
#  {'token_idx': 36442,
#   'pos': 78,
#   'id': '36442 78',
#   'nexts': ['47 79'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 79,
#   'id': '47 79',
#   'nexts': ['78431 80'],
#   'score': 0},
#  {'token_idx': 78431,
#   'pos': 80,
#   'id': '78431 80',
#   'nexts': ['2 81'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 78,
#   'id': '127557 78',
#   'nexts': ['47 79'],
#   'score': 0},
#  {'token_idx': 4358,
#   'pos': 76,
#   'id': '4358 76',
#   'nexts': ['1295 77'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 78,
#   'id': '70 78',
#   'nexts': ['2 79', '7082 79', '14098 79'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 79,
#   'id': '7082 79',
#   'nexts': ['47 80'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 80,
#   'id': '46684 80',
#   'nexts': ['2 81', '23 81', '47 81'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 83,
#   'id': '70 83',
#   'nexts': ['2 84', '130481 84', '37515 84'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 84,
#   'id': '130481 84',
#   'nexts': ['2 85'],
#   'score': 0},
#  {'token_idx': 37515,
#   'pos': 84,
#   'id': '37515 84',
#   'nexts': ['525 85'],
#   'score': 0},
#  {'token_idx': 525,
#   'pos': 85,
#   'id': '525 85',
#   'nexts': ['259 86'],
#   'score': 0},
#  {'token_idx': 272,
#   'pos': 87,
#   'id': '272 87',
#   'nexts': ['111 88'],
#   'score': 0},
#  {'token_idx': 111, 'pos': 88, 'id': '111 88', 'nexts': ['2 89'], 'score': 0},
#  {'token_idx': 70,
#   'pos': 83,
#   'id': '70 83',
#   'nexts': ['2 84', '37515 84'],
#   'score': 0},
#  {'token_idx': 525, 'pos': 85, 'id': '525 85', 'nexts': ['2 86'], 'score': 0},
#  {'token_idx': 345, 'pos': 76, 'id': '345 76', 'nexts': ['5 77'], 'score': 0},
#  {'token_idx': 5, 'pos': 77, 'id': '5 77', 'nexts': ['2 78'], 'score': 0},
#  {'token_idx': 7082,
#   'pos': 76,
#   'id': '7082 76',
#   'nexts': ['2 77', '8060 77', '4358 77', '36442 77', '127557 77'],
#   'score': 0},
#  {'token_idx': 8060,
#   'pos': 77,
#   'id': '8060 77',
#   'nexts': ['2 78', '23 78', '47 78'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 78, 'id': '47 78', 'nexts': ['2 79'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 77,
#   'id': '4358 77',
#   'nexts': ['2 78', '47 78', '23 78'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 78,
#   'id': '47 78',
#   'nexts': ['78431 79'],
#   'score': 0},
#  {'token_idx': 78431,
#   'pos': 79,
#   'id': '78431 79',
#   'nexts': ['70 80'],
#   'score': 0},
#  {'token_idx': 70, 'pos': 80, 'id': '70 80', 'nexts': ['2 81'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 78,
#   'id': '23 78',
#   'nexts': ['181952 79'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 79,
#   'id': '181952 79',
#   'nexts': ['70 80'],
#   'score': 0},
#  {'token_idx': 36442,
#   'pos': 77,
#   'id': '36442 77',
#   'nexts': ['2 78', '23 78', '47 78'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 78,
#   'id': '47 78',
#   'nexts': ['2 79', '30641 79', '78431 79'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 79,
#   'id': '30641 79',
#   'nexts': ['70 80'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 77,
#   'id': '127557 77',
#   'nexts': ['2 78', '23 78', '47 78'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 78,
#   'id': '23 78',
#   'nexts': ['2 79', '30641 79'],
#   'score': 0},
#  {'token_idx': 30641,
#   'pos': 79,
#   'id': '30641 79',
#   'nexts': ['214 80'],
#   'score': 0},
#  {'token_idx': 214, 'pos': 80, 'id': '214 80', 'nexts': ['2 81'], 'score': 0},
#  {'token_idx': 70,
#   'pos': 80,
#   'id': '70 80',
#   'nexts': ['130481 81'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 81,
#   'id': '130481 81',
#   'nexts': ['259 82'],
#   'score': 0},
#  {'token_idx': 259,
#   'pos': 82,
#   'id': '259 82',
#   'nexts': ['272 83'],
#   'score': 0},
#  {'token_idx': 272, 'pos': 83, 'id': '272 83', 'nexts': ['2 84'], 'score': 0},
#  {'token_idx': 6, 'pos': 70, 'id': '6 70', 'nexts': ['4 71'], 'score': 0},
#  {'token_idx': 4,
#   'pos': 71,
#   'id': '4 71',
#   'nexts': ['2 72', '191618 71', '23 71', '1210 71', '24159 71'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 71,
#   'id': '191618 71',
#   'nexts': ['7082 72'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 72,
#   'id': '7082 72',
#   'nexts': ['127557 73'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 73,
#   'id': '127557 73',
#   'nexts': ['2 74'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 71,
#   'id': '23 71',
#   'nexts': ['2 72', '10 72', '33938 72', '142 72'],
#   'score': 0},
#  {'token_idx': 10,
#   'pos': 72,
#   'id': '10 72',
#   'nexts': ['45880 73'],
#   'score': 0},
#  {'token_idx': 45880,
#   'pos': 73,
#   'id': '45880 73',
#   'nexts': ['47 74'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 74, 'id': '47 74', 'nexts': ['4358 75'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 75,
#   'id': '4358 75',
#   'nexts': ['70 76'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 76,
#   'id': '70 76',
#   'nexts': ['14098 77'],
#   'score': 0},
#  {'token_idx': 14098,
#   'pos': 77,
#   'id': '14098 77',
#   'nexts': ['46684 78'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 78,
#   'id': '46684 78',
#   'nexts': ['78431 79'],
#   'score': 0},
#  {'token_idx': 130481,
#   'pos': 81,
#   'id': '130481 81',
#   'nexts': ['2 82'],
#   'score': 0},
#  {'token_idx': 111, 'pos': 73, 'id': '111 73', 'nexts': ['2 74'], 'score': 0},
#  {'token_idx': 142, 'pos': 72, 'id': '142 72', 'nexts': ['2 73'], 'score': 0},
#  {'token_idx': 1210,
#   'pos': 71,
#   'id': '1210 71',
#   'nexts': ['2 72', '47 72', '237 72', '23 72'],
#   'score': 0},
#  {'token_idx': 47, 'pos': 72, 'id': '47 72', 'nexts': ['40 73'], 'score': 0},
#  {'token_idx': 40, 'pos': 73, 'id': '40 73', 'nexts': ['343 74'], 'score': 0},
#  {'token_idx': 343, 'pos': 74, 'id': '343 74', 'nexts': ['2 75'], 'score': 0},
#  {'token_idx': 237,
#   'pos': 72,
#   'id': '237 72',
#   'nexts': ['764 73'],
#   'score': 0},
#  {'token_idx': 764,
#   'pos': 73,
#   'id': '764 73',
#   'nexts': ['2 74', '221 74', '40 74'],
#   'score': 0},
#  {'token_idx': 221,
#   'pos': 74,
#   'id': '221 74',
#   'nexts': ['46526 75'],
#   'score': 0},
#  {'token_idx': 46526,
#   'pos': 75,
#   'id': '46526 75',
#   'nexts': ['7082 76'],
#   'score': 0},
#  {'token_idx': 40, 'pos': 74, 'id': '40 74', 'nexts': ['5447 75'], 'score': 0},
#  {'token_idx': 5447,
#   'pos': 75,
#   'id': '5447 75',
#   'nexts': ['7082 76'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 72,
#   'id': '23 72',
#   'nexts': ['2 73', '70 73', '10 73', '33938 73'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 73,
#   'id': '70 73',
#   'nexts': ['15673 74'],
#   'score': 0},
#  {'token_idx': 15673,
#   'pos': 74,
#   'id': '15673 74',
#   'nexts': ['7 75'],
#   'score': 0},
#  {'token_idx': 7, 'pos': 75, 'id': '7 75', 'nexts': ['111 76'], 'score': 0},
#  {'token_idx': 111,
#   'pos': 76,
#   'id': '111 76',
#   'nexts': ['191618 77'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 77,
#   'id': '191618 77',
#   'nexts': ['7082 78'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 78,
#   'id': '7082 78',
#   'nexts': ['127557 79'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 79,
#   'id': '127557 79',
#   'nexts': ['2 80'],
#   'score': 0},
#  {'token_idx': 10,
#   'pos': 73,
#   'id': '10 73',
#   'nexts': ['45880 74'],
#   'score': 0},
#  {'token_idx': 45880,
#   'pos': 74,
#   'id': '45880 74',
#   'nexts': ['2 75', '100 75', '47 75'],
#   'score': 0},
#  {'token_idx': 100,
#   'pos': 75,
#   'id': '100 75',
#   'nexts': ['7082 76'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 75,
#   'id': '47 75',
#   'nexts': ['2 76', '40 76', '4358 76'],
#   'score': 0},
#  {'token_idx': 40, 'pos': 76, 'id': '40 76', 'nexts': ['343 77'], 'score': 0},
#  {'token_idx': 343, 'pos': 77, 'id': '343 77', 'nexts': ['2 78'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 76,
#   'id': '4358 76',
#   'nexts': ['70 77'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 77,
#   'id': '70 77',
#   'nexts': ['2 78', '23295 78', '7082 78'],
#   'score': 0},
#  {'token_idx': 23295,
#   'pos': 78,
#   'id': '23295 78',
#   'nexts': ['78431 79'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 78,
#   'id': '7082 78',
#   'nexts': ['78431 79'],
#   'score': 0},
#  {'token_idx': 33938,
#   'pos': 73,
#   'id': '33938 73',
#   'nexts': ['111 74'],
#   'score': 0},
#  {'token_idx': 111,
#   'pos': 74,
#   'id': '111 74',
#   'nexts': ['2 75', '345 75'],
#   'score': 0},
#  {'token_idx': 345, 'pos': 75, 'id': '345 75', 'nexts': ['5 76'], 'score': 0},
#  {'token_idx': 5, 'pos': 76, 'id': '5 76', 'nexts': ['2 77'], 'score': 0},
#  {'token_idx': 24159,
#   'pos': 71,
#   'id': '24159 71',
#   'nexts': ['2 72', '47 72', '237 72', '191618 72', '23 72'],
#   'score': 0},
#  {'token_idx': 764,
#   'pos': 73,
#   'id': '764 73',
#   'nexts': ['2 74', '40 74', '221 74'],
#   'score': 0},
#  {'token_idx': 5447,
#   'pos': 75,
#   'id': '5447 75',
#   'nexts': ['2 76'],
#   'score': 0},
#  {'token_idx': 46526,
#   'pos': 75,
#   'id': '46526 75',
#   'nexts': ['2 76'],
#   'score': 0},
#  {'token_idx': 191618,
#   'pos': 72,
#   'id': '191618 72',
#   'nexts': ['2 73', '127557 73', '4358 73', '14098 73', '345 73'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 73,
#   'id': '127557 73',
#   'nexts': ['1295 74'],
#   'score': 0},
#  {'token_idx': 1295,
#   'pos': 74,
#   'id': '1295 74',
#   'nexts': ['70 75'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 75,
#   'id': '70 75',
#   'nexts': ['2 76', '7082 76'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 76,
#   'id': '7082 76',
#   'nexts': ['23 77'],
#   'score': 0},
#  {'token_idx': 23,
#   'pos': 77,
#   'id': '23 77',
#   'nexts': ['181952 78'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 78,
#   'id': '181952 78',
#   'nexts': ['70 79'],
#   'score': 0},
#  {'token_idx': 70, 'pos': 79, 'id': '70 79', 'nexts': ['2 80'], 'score': 0},
#  {'token_idx': 4358,
#   'pos': 73,
#   'id': '4358 73',
#   'nexts': ['1295 74'],
#   'score': 0},
#  {'token_idx': 70,
#   'pos': 75,
#   'id': '70 75',
#   'nexts': ['2 76', '7082 76', '14098 76'],
#   'score': 0},
#  {'token_idx': 7082,
#   'pos': 76,
#   'id': '7082 76',
#   'nexts': ['47 77'],
#   'score': 0},
#  {'token_idx': 47,
#   'pos': 77,
#   'id': '47 77',
#   'nexts': ['78431 78'],
#   'score': 0},
#  {'token_idx': 14098,
#   'pos': 76,
#   'id': '14098 76',
#   'nexts': ['2 77'],
#   'score': 0},
#  {'token_idx': 14098,
#   'pos': 73,
#   'id': '14098 73',
#   'nexts': ['46684 74'],
#   'score': 0},
#  {'token_idx': 46684,
#   'pos': 74,
#   'id': '46684 74',
#   'nexts': ['127557 75'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 75,
#   'id': '127557 75',
#   'nexts': ['23 76'],
#   'score': 0},
#  {'token_idx': 181952,
#   'pos': 77,
#   'id': '181952 77',
#   'nexts': ['2 78'],
#   'score': 0},
#  {'token_idx': 345, 'pos': 73, 'id': '345 73', 'nexts': ['5 74'], 'score': 0},
#  {'token_idx': 5, 'pos': 74, 'id': '5 74', 'nexts': ['2 75'], 'score': 0},
#  {'token_idx': 23,
#   'pos': 72,
#   'id': '23 72',
#   'nexts': ['2 73', '1919 73', '70 73', '10 73', '142 73'],
#   'score': 0},
#  {'token_idx': 1919,
#   'pos': 73,
#   'id': '1919 73',
#   'nexts': ['38694 74'],
#   'score': 0},
#  {'token_idx': 38694,
#   'pos': 74,
#   'id': '38694 74',
#   'nexts': ['100 75'],
#   'score': 0},
#  {'token_idx': 127557,
#   'pos': 77,
#   'id': '127557 77',
#   'nexts': ['2 78'],
#   'score': 0},
#  {'token_idx': 7, 'pos': 75, 'id': '7 75', 'nexts': ['2 76'], 'score': 0},
#  {'token_idx': 45880,
#   'pos': 74,
#   'id': '45880 74',
#   'nexts': ['2 75', '100 75'],
#   'score': 0},
#  {'token_idx': 100, 'pos': 75, 'id': '100 75', 'nexts': ['2 76'], 'score': 0},
#  {'token_idx': 142,
#   'pos': 73,
#   'id': '142 73',
#   'nexts': ['2 74', '81887 74'],
#   'score': 0},
#  {'token_idx': 81887,
#   'pos': 74,
#   'id': '81887 74',
#   'nexts': ['2 75'],
#   'score': 0}]

# %%
def get_validnext (pos, nlist):
    retval = ""
    for n in nlist:
        if pos< int(n.split()[1]):
            retval = n
            if "2 " not in n:
                return retval
    if len(retval)>0:
        return retval
    print("no valid")
    print(pos)
    print(nlist)
    return ""

def p_wnext(pgraph):
    nid = '0 0'
    for tokd in pgraph:
        if tokd['id']==nid:
            print(xlm_tok.decode(tokd['token_idx']))
            nid = get_validnext(tokd['pos'], tokd['nexts'])
            
            #print(tokd)
    print(nid)
            
p_wnext(processedgraphs[0])

# %%
# Attention mask code (TODO needs some updating)
if os.path.exists('./torchsaved/'+LOADED['amasks']):
        print("using loaded masks")
        attmasks = torch.load('./torchsaved/'+LOADED['amasks']).to(device)
else:
    print("creating new masks")
    masktmp = get_allamasks()
    attmasks = torch.stack(masktmp).to(device)
    torch.save(attmasks, './torchsaved/'+LOADED['amasks'])
# Out:
# using loaded masks

# %%
# get tokenized inputs with posids (TODO needs an update for src/tgt format)
sents, posids = create_inputs(processedgraphs)

# %%
sents.to(device)
posids.to(device)
attmasks.to(device)

# %%
attmasks.shape
# Out:
# torch.Size([101,512,512])

# %%
import torch.nn as nn
from transformers import AutoModel
# Returns Token Scores For Each (Sum becomes Regression)
class XLMCometEmbeds(nn.Module):
    
    def __init__(self, drop_rate=0.1):
        # TODO should we be freezing layers?
        super().__init__()
        
        self.xlmroberta = AutoModel.from_pretrained('xlm-roberta-base')
        # Num labels 1 should just indicate regression (?)
        self.regressor = nn.Sequential(
            nn.Dropout(drop_rate),
            nn.Linear(self.xlmroberta.config.hidden_size, 1), 
        )
        self.to(device)
        
    def forward(self, input_ids, positions, attention_masks):
        # don't finetune xlmroberta model
        #with torch.no_grad():
        word_rep, sentence_rep = self.xlmroberta(input_ids, position_ids = positions, attention_mask=attention_masks, encoder_attention_mask=attention_masks, return_dict=False)
        # use the first <s> token as a CLS token, TODO experiment with using the sum of 
        # ensure padding not factored in
        #word_rep = word_rep*(input_ids>0).unsqueeze(-1)
        res = []
        for w in word_rep:
            res.append(self.regressor(w))
            
        word_rep = word_rep*(input_ids>0).unsqueeze(-1)
        #outputs = self.regressor(torch.sum(word_rep, 1))
        #print("Shape: ", outputs.shape)
        return word_rep

# %%
del model

# %%
model = XLMCometEmbeds(drop_rate=0.1)
model.load_state_dict(torch.load("./torchsaved/maskedcont3.pt"))
model.eval()

# %%
model.regressor[1].weight

# %%
model.regressor[1].bias

# %%
with torch.no_grad():
    outs = model(sents, posids, attmasks)

# %%
scores = torch.inner(outs, model.regressor[1].weight).squeeze(-1)

# %%
# Out:
# torch.Size([500])

# %%
# set scores computed for each token by the model
def set_pgscores(pgraphs, scores):
    #idlist = get_idlist(pgraph)
    for p in range(len(pgraphs)):
        pgraph = pgraphs[p]
        for i in range(min(len(pgraph),512)):
            pgraph[i]['score'] = scores[p][i]
            if pgraph[i]['token_idx']>0:
                if pgraph[i]['score']==0:
                    print(i)
                    print(p)
    return pgraphs

# topological sort the graphs, make sure that nodes that are next always come next in the list
def topo_sort_pgraph(pgraph):
    # reverse ordering
    pgraph.reverse()
    # for all tokens
    i = 0
    while i < min(len(pgraph),512):
        ns = pgraph[i]
        # check if any tokens that come after actually should be before
        for j in range(i, min(len(pgraph),512)):
            # if so, re-insert right before in list
            if pgraph[j]['id'] in ns:
                tmp = pgraph[j]
                del pgraph[j]
                pgraph.insert(i, tmp)
                i+=1
        i+=1
        
def prepare_pgraphs(pgraphs, scores):
    res = []
    # make a deep copy of processed graphs
    for p in pgraphs:
        res.append([x for x in p])
    # set scores for stuff
    set_pgscores(res, scores)
    # do topological sorting
    for r in res:
        topo_sort_pgraph(r)
    return res
    
    

prepared_pgraphs = prepare_pgraphs(processedgraphs, scores)
# Out:
# 498
# 55
# 499
# 55
# 498
# 57
# 499
# 57
# 498
# 82
# 499
# 82
# 498
# 90
# 499
# 90

# %%
# given a list of sub-scores (topological flattening of the graph), use dp to get the highest scoring path
# idlist has the corresponding graph ids for 
# would need to do a sort on pgrapaps that makes sure that no next node is before in the linear ordering
# reverse since we're using nexts
# TODO simplify code to not need so many data structures
def dp_best_path(pgraphs, graph):
    bplist = []
    bsco_list =[]
    idlist = get_idlist(pgraphs)
    for i in range(len(idlist)):
        bpath = []
        cur = pgraphs[i]
            
        # get the highest prev from ahead to use
        mval = -10
        maxnext = None
        for n in cur['nexts']:
            try:
                if graph[n]['bestsco']>mval:
                    mval = graph[n]['bestsco']
                    maxnext = graph[n]
            except:
                ""

        # add in scores / path from that prev
        if maxnext==None:
            bpath.append(i)
            bplist.append(bpath)
            bsco_list.append(cur['score'])
            # check if this is how things work in python
            graph[cur['id']]['bestsco'] = cur['score']
            graph[cur['id']]['plist'] = bpath
            continue
        bpath.extend(maxnext['plist']+[i])
        bplist.append(bpath)
        bsco_list.append(cur['score']+mval)
        graph[cur['id']]['bestsco'] = cur['score']+mval
        graph[cur['id']]['plist'] = bpath
        #print(bpath)
    return bplist[-1], bsco_list[-1]

def get_idlist(pgraph):
    return [p['id'] for p in pgraph]

def dp_pgraph(pgraph):
    graph = {}
    for p in pgraph:
        # TODO check if scores are negative number compatible
        p['bestsco'] = 0
        p['plist'] = []
        graph[p['id']] = p
    bestpath, bso = dp_best_path(pgraph, graph)
    print(bsco)
    bestpath.reverse()
    return [pgraph[x]['token_idx'] for x in bestpath]
        
    
bp = dp_pgraph(prepared_pgraphs[0])
# Out:
# tensor(0.1371, device='cuda:2', grad_fn=<AddBackward0>)

# %%
examplenum = 21
print(xlm_tok.decode(dp_pgraph(prepared_pgraphs[examplenum])))
print(refs[examplenum])
# Out:
# tensor(0.1371, device='cuda:2', grad_fn=<AddBackward0>)
# <s> Mais le coût du nouveau vaccin devrait être bien inférieur car il transforme les cellules du foie en usines à anticorps.</s><s> But the new vaccine should cost much less because it turns liver cells into antibody factories.
# But the cost of the new vaccine is likely to be far lower, because it turns liver cells into antibody factories.

# %%
cnt = 0
for t in processedgraphs[0]:
    if t['token_idx']==0:
        print(t)
cnt
# Out:
# {'token_idx': 0, 'pos': 0, 'id': '0 0', 'nexts': ['636 1'], 'score': tensor(0., device='cuda:2', grad_fn=<SelectBackward0>), 'bestsco': tensor(0., device='cuda:2', grad_fn=<SelectBackward0>), 'plist': [364]}
# {'token_idx': 0, 'pos': 49, 'id': '0 49', 'nexts': ['581 50'], 'score': tensor(0., device='cuda:2', grad_fn=<SelectBackward0>), 'bestsco': tensor(0., device='cuda:2', grad_fn=<SelectBackward0>), 'plist': [315]}
# 0

# %%
bert_tok.decode(0)

# %%
processedgraphs[0][0]

# %%
bert_tok("<s>")

# %%
' </s> en_XX The US President was to receive Iraq i Prime Minister No uri Al Malik i Friday , November 1 , 2013 in an effort to se ek US assistance in fighting the worst wa ve of violence in five years'

# %%
import json

# %%
lat4[0].keys()
# Out:
# dict_keys(['ref', 'src', 'topinitial', 'cands', 'modelscores', 'comranked', 'cometscores', 'qeranked', 'qescores', 'rescores', 'sco_ranks'])
