# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
from os import listdir
from IPython.display import display, HTML
import json
import re

# %%
test = load_dataset("xsum", split='test')
#switch to raw maynes file if maynez_docset doesn't exist yet, use method below to generate
df = pd.read_csv('./maynez_docset.csv')
# Out:
# Using custom data configuration default
# Reusing dataset xsum (/home/prasann/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934)

# %%
# matchse maynez examples to corresponding xsum documents
def load_maynez_docset():
    doclist = []
    sumlist = []
    indlist = []
    for index, row in df.iterrows():
        t = test['id'].index(str(row['bbcid']))
        if t>=0:
            doclist.append(test[t]['document'])
            sumlist.append(test[t]['summary']);
            indlist.append(t)
    df['doc'] = doclist
    df['corr'] = sumlist
    df['dataind'] = indlist
    df.to_csv('maynez_docset.csv', index=False)
    return df

# %%
#TODO insert this into lattice gen code, make dataset subset based on this array
test.select(df['dataind'].unique())
# Out:
# Dataset({
#     features: ['document', 'summary', 'id'],
#     num_rows: 498
# })

# %%
df.loc[df.is_factual=='yes']
# Out:
#          bbcid   system                                            summary  \
# 9     27838706  BERTS2S  aberdeen have appointed arbroath boss paul she...
# 10    27838706  BERTS2S  aberdeen have appointed arbroath boss paul she...
# 21    31566848  BERTS2S  a woman was assaulted and assaulted in a mcdon...
# 22    31566848  BERTS2S  a woman was assaulted and assaulted in a mcdon...
# 23    31566848  BERTS2S  a woman was assaulted and assaulted in a mcdon...
# ...        ...      ...                                                ...
# 5444  36086291    PtGen  prince william has said she is ``incredibly im...
# 5445  36086291    PtGen  prince william has said she is ``incredibly im...
# 5446  36086291    PtGen  prince william has said she is ``incredibly im...
# 5528  37895159    PtGen  bournemouth manager eddie howe has urged his p...
# 5572  19330169    PtGen  actress [UNK] o'donnell has said she was ``luc...
#
#      is_factual worker_id                                                doc  \
# 9           yes     wid_0  Former Dons midfielder Sheerin, 39, has been p...
# 10          yes     wid_1  Former Dons midfielder Sheerin, 39, has been p...
# 21          yes     wid_0  The victim was queuing for food at the branch ...
# 22          yes     wid_1  The victim was queuing for food at the branch ...
# 23          yes     wid_2  The victim was queuing for food at the branch ...
# ...         ...       ...                                                ...
# 5444        yes     wid_0  He was speaking in a BBC interview in which he...
# 5445        yes     wid_1  He was speaking in a BBC interview in which he...
# 5446        yes     wid_2  He was speaking in a BBC interview in which he...
# 5528        yes     wid_0  The Cherries went down 2-1 at Sunderland on Sa...
# 5572        yes     wid_2  The 50 year-old said she was "lucky to be here...
#
#                                                    corr  dataind
# 9     Paul Sheerin has left his post as Arbroath man...     7268
# 10    Paul Sheerin has left his post as Arbroath man...     7268
# 21    A woman had her hair set alight in a "nasty an...     2915
# 22    A woman had her hair set alight in a "nasty an...     2915
# 23    A woman had her hair set alight in a "nasty an...     2915
# ...                                                 ...      ...
# 5444  Prince William has answered criticism of his c...     1799
# 5445  Prince William has answered criticism of his c...     1799
# 5446  Prince William has answered criticism of his c...     1799
# 5528  Bournemouth boss Eddie Howe admits his side's ...     7810
# 5572  US comedian and talk show host Rosie O'Donnell...     3272
#
# [582 rows x 8 columns]

# %%
# Out:
# 2022-03-25 02:35:11.820359: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-25 02:35:11.820401: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /mnt/data1/prasann/latticegen/lattice-generation/factuality_explore.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bdenali.csres.utexas.edu/mnt/data1/prasann/latticegen/lattice-generation/factuality_explore.ipynb#ch0000005vscode-remote?line=0'>1</a> ds.export('xsumtrain.csv')
#
# File ~/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py:3160, in Dataset.export(self, filename, format)
#    <a href='file:///home/prasann/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py?line=3156'>3157</a>     for ex in self:
#    <a href='file:///home/prasann/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py?line=3157'>3158</a>         yield serialize_example(ex)
# -> <a href='file:///home/prasann/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py?line=3159'>3160</a> assert self._format_type == "numpy", "Dataset format must be numpy before exporting"
#    <a href='file:///home/prasann/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py?line=3160'>3161</a> assert filename.endswith(".tfrecord")
#    <a href='file:///home/prasann/miniconda3/envs/latenv/lib/python3.8/site-packages/datasets/arrow_dataset.py?line=3161'>3162</a> tf_dataset = tf.data.Dataset.from_generator(generator, output_types=tf.string, output_shapes=())
#
# AssertionError: Dataset format must be numpy before exporting

# %%
genpath = "./output/text/"
vispath = "./output/html/"
out = "sum_xsum_astar_16_15_False_0.4_True_False_4_5_zip_0.75_0.0_0.9/"
allfiles = listdir(genpath+out)
filterid = ".*(?:\D|^)(\d+)"

def filter_json(afs):
    result = []
    for a in afs:
        if 'json' in a:
            result.append(a)
    return result

def get_top (genlist):
    maxg = -1000
    best = []
    for g in genlist:
        if g[2]['rouge2']> maxg:
            maxg = g[2]['rouge2']
            best = g
    return best

def compare_maynez (ind):
    files = filter_json(allfiles)
    # read file
    with open(genpath+out+files[ind], 'r') as myfile:
        data=myfile.read()

    # parse file
    obj = json.loads(data)
    #display(HTML(data))
    xsumid = (re.search(filterid, files[ind])).group(1)
    print("ID: "+str(xsumid))
    
    print("Top1: ")
    print(get_top(obj['sample']))
    a  = df.loc[df.bbcid==int(xsumid)]
    maynez_false = a.loc[a['is_factual'].str.contains("no")]
    maynez_yes = a.loc[a['is_factual'].str.contains("yes")]
    print("Correct Summary:\n"+maynez_false.iloc[0]['corr']+"\n")
    print ("Maynez summaries (non-factual) ")
    mf = maynez_false['summary'].unique()
    my = maynez_yes['summary'].unique()
    for m in range(0, len(mf)):
        print("Summ "+str(m)+":"+mf[m])

    print ("Maynez summaries (factual) ")
    for m in range(0, len(my)):
        print("Summ "+str(m)+":"+my[m])
    print("\n\n")

# %%
for i in range(0, 21):
    compare_maynez(i)
# Out:
# ID: 35977985
# Top1:
# ['Braintree manager Keith Cowley has hailed his team\'s performance after their 1-0 defeat by Barrow is their "toughest challenge to date" despite the defeat.', 37, {'rouge2': 0.13636363636363635}]
# Correct Summary:
# Braintree manager Danny Cowley said the task ahead of his team is "a brilliant challenge" after the defeat at Barrow.
#
# Maynez summaries (non-factual)
# Summ 0:braintree boss steve cowley says his side's 1-0 victory over barrow in the national league was " remarkable ".
# Summ 1:cowdenbeath head coach shaun barrow says his side are in a " tough " way to claim their first national league win of the season.
# Summ 2:braintree town manager gary cowley says his side have a ``good chance''of winning the national league play-offs.
# Summ 3:braintree manager nicola cowley has urged his players to be ``tough''after winning the premier league title.
# Maynez summaries (factual)
# Summ 0:braintree boss steve cowley says his side's 1-0 victory over barrow in the national league was " remarkable ".
# Summ 1:cowdenbeath head coach shaun barrow says his side are in a " tough " way to claim their first national league win of the season.
# Summ 2:braintree town manager gary cowley says his side have a ``good chance''of winning the national league play-offs.
# Summ 3:braintree manager nicola cowley has urged his players to be ``tough''after winning the premier league title.
#
#
#
# ID: 15291712
# Top1:
# ["As David Cameron prepares for the first Commons vote on the UK's membership of the European Union, what do its MPs think about the issue?", 30, {'rouge2': 0.07692307692307691}]
# Correct Summary:
# Two-thirds of Conservative MPs want to renegotiate the UK's relationship with Europe but are too scared to reveal their true Eurosceptic sentiment, claim Conservative Party insiders.
#
# Maynez summaries (non-factual)
# Summ 0:in the wake of the uk's withdrawal from the european union, one of the most recognisable views on brexit is that the
# Summ 1:david cameron's claim that he would be a tory tory leader if the conservatives win the general election is a tory leadership battle.
# Summ 2:it has been a momentous year for conservative mps.
# Maynez summaries (factual)
# Summ 0:in the wake of the uk's withdrawal from the european union, one of the most recognisable views on brexit is that the
# Summ 1:david cameron's claim that he would be a tory tory leader if the conservatives win the general election is a tory leadership battle.
# Summ 2:it has been a momentous year for conservative mps.
#
#
#
# ID: 39405778
# Top1:
# ['Plans for a glass tower on the top of a former power station in Southampton have been unveiled.', 21, {'rouge2': 0.048780487804878044}]
# Correct Summary:
# A 650ft (198m) power station chimney could be converted into a public viewing tower and restaurant overlooking the Hampshire coast, under plans released by developers.
#
# Maynez summaries (non-factual)
# Summ 0:plans have been submitted for a glass tower on the edge of southampton seafront.
# Summ 1:the site of a former power station in the solent is set to be turned into a former oil chimney site.
# Summ 2:plans for a disused power station in southampton have been given the go-ahead by the government.
# Summ 3:construction work has started on a new # [UNK] power station in brighton, which would create a new power station in brighton.
# Maynez summaries (factual)
# Summ 0:plans have been submitted for a glass tower on the edge of southampton seafront.
# Summ 1:the site of a former power station in the solent is set to be turned into a former oil chimney site.
# Summ 2:plans for a disused power station in southampton have been given the go-ahead by the government.
# Summ 3:construction work has started on a new # [UNK] power station in brighton, which would create a new power station in brighton.
#
#
#
# ID: 38213922
# Top1:
# ['Manchester City and Chelsea have been charged with violent conduct by the Football Association for failing to control their players during the Premier League game between the sides on Saturday.', 32, {'rouge2': 0.8076923076923076}]
# Correct Summary:
# Manchester City and Chelsea have been charged by the Football Association for failing to control their players during the Premier League game on Saturday.
#
# Maynez summaries (non-factual)
# Summ 0:manchester city and manchester city have been charged by the football association for violent conduct during saturday's premier league game at etihad stadium.
# Summ 1:manchester city have been given a one-match touchline ban by the football association for violent conduct during their 2-0 defeat by chelsea.
# Summ 2:manchester city manager jose mourinho has been charged by the football association for failing to reach the fa cup.
# Maynez summaries (factual)
# Summ 0:manchester city and manchester city have been charged by the football association for violent conduct during saturday's premier league game at etihad stadium.
# Summ 1:manchester city have been given a one-match touchline ban by the football association for violent conduct during their 2-0 defeat by chelsea.
# Summ 2:manchester city manager jose mourinho has been charged by the football association for failing to reach the fa cup.
#
#
#
# ID: 40642906
# Top1:
# ['Featherstone Rovers have appointed Kevin Duffy as head coach.', 14, {'rouge2': 0.5454545454545454}]
# Correct Summary:
# Featherstone Rovers have appointed John Duffy as head coach following the departure of Jon Sharp.
#
# Maynez summaries (non-factual)
# Summ 0:castleford tigers have appointed former scotland international kevin duffy as their new head coach.
# Summ 1:leigh centurions have appointed former scotland international matt duffy as their new head coach.
# Summ 2:leigh centurions have appointed former scotland international jamie duffy as their new head coach on a two-year deal.
# Summ 3:featherstone head coach lee duffy has been ruled out of the rest of the super league season with a shoulder injury.
# Maynez summaries (factual)
# Summ 0:castleford tigers have appointed former scotland international kevin duffy as their new head coach.
# Summ 1:leigh centurions have appointed former scotland international matt duffy as their new head coach.
# Summ 2:leigh centurions have appointed former scotland international jamie duffy as their new head coach on a two-year deal.
# Summ 3:featherstone head coach lee duffy has been ruled out of the rest of the super league season with a shoulder injury.
#
#
#
# ID: 39979364
# Top1:
# ["The medals for the World Para Athletics Championships medals have been unveiled in London ahead of this summer's World Championships in August.", 26, {'rouge2': 0.2553191489361702}]
# Correct Summary:
# The World Championships medals that will be won in London this summer have been revealed, with a shape based on the curves of an athletics track.
#
# Maynez summaries (non-factual)
# Summ 0:the london 2012 para-athletics world championships will feature the latest design of its para-medals for the first time.
# Summ 1:the world para athletics championships are taking place in london on friday, 3 august, for the first time.
# Maynez summaries (factual)
# Summ 0:the london 2012 para-athletics world championships will feature the latest design of its para-medals for the first time.
# Summ 1:the world para athletics championships are taking place in london on friday, 3 august, for the first time.
#
#
#
# ID: 39037666
# Top1:
# ['The White House has condemned a series of bomb threats to Jewish community centres in the US after a further five centres received threats on Monday.', 28, {'rouge2': 0.34782608695652173}]
# Correct Summary:
# The FBI is investigating another wave of bomb threats to Jewish facilities in the US after 11 sites were evacuated on Monday.
#
# Maynez summaries (non-factual)
# Summ 0:a number of jewish community centres in the us have been threatened by hoax bomb threats, the white house says.
# Summ 1:jewish and jewish centres across the us have been targeted by jewish threats, the white house has said.
# Summ 2:the number of jewish community centres in the us and us has fallen to its lowest level in recent weeks, the white house has said.
# Maynez summaries (factual)
# Summ 0:a number of jewish community centres in the us have been threatened by hoax bomb threats, the white house says.
# Summ 1:jewish and jewish centres across the us have been targeted by jewish threats, the white house has said.
# Summ 2:the number of jewish community centres in the us and us has fallen to its lowest level in recent weeks, the white house has said.
#
#
#
# ID: 40122729
# Top1:
# ['All images are copyrighted.r', 10, {'rouge2': 0.0}]
# Correct Summary:
# We actually don't have a picture of Thortonloch beach - yet - so if you have a great shot of this, or if one of our other pictures isn't of quite the right spot, or indeed if you have any other great images from anywhere around Scotland, you can send us your pictures here.
#
# Maynez summaries (non-factual)
# Summ 0:loch lomond has been described as the uk's best place to swim.
# Summ 1:scotland's men's beaches have been ranked at the best in the world, with the best performance in the country.
# Summ 2:all pictures are copyrighted.
# Summ 3:team gb's olympic team team gb have been boosted by [UNK] in the last of the world championships in glasgow.
# Maynez summaries (factual)
# Summ 0:loch lomond has been described as the uk's best place to swim.
# Summ 1:scotland's men's beaches have been ranked at the best in the world, with the best performance in the country.
# Summ 2:all pictures are copyrighted.
# Summ 3:team gb's olympic team team gb have been boosted by [UNK] in the last of the world championships in glasgow.
#
#
#
# ID: 40285994
# Top1:
# ['The Grenfell Tower fire victims should be re-housed locally if necessary, Jeremy Corbyn has said.', 22, {'rouge2': 0.34285714285714286}]
# Correct Summary:
# Properties in North Kensington should be "requisitioned if necessary" for people left homeless after the Grenfell Tower fire, Jeremy Corbyn says.
#
# Maynez summaries (non-factual)
# Summ 0:jeremy corbyn has said the poorest residents in the south of england should be rehoused.
# Summ 1:sadiq khan has praised the grenfell tower fire as " frightened " and " frightened ".
# Summ 2:jeremy corbyn has defended the grenfell tower fire following the grenfell tower fire.
# Summ 3:theresa may has said he is ``angry and angry''that the grenfell tower fire was ``the wealthiest part of the country''.
# Maynez summaries (factual)
# Summ 0:jeremy corbyn has said the poorest residents in the south of england should be rehoused.
# Summ 1:sadiq khan has praised the grenfell tower fire as " frightened " and " frightened ".
# Summ 2:jeremy corbyn has defended the grenfell tower fire following the grenfell tower fire.
# Summ 3:theresa may has said he is ``angry and angry''that the grenfell tower fire was ``the wealthiest part of the country''.
#
#
#
# ID: 37565125
# Top1:
# ["Tributes have been paid to Rod Temperton, the British songwriter who wrote Michael Jackson's Thriller and other hits, following his death.", 30, {'rouge2': 0.42105263157894735}]
# Correct Summary:
# Rod Temperton, the British songwriter best known for Michael Jackson's Thriller and Rock With You, has died.
#
# Maynez summaries (non-factual)
# Summ 0:singer rod temperton, who wrote the hit album michael jackson, has died at the age of 89.
# Summ 1:singer rodton jackson has died at the age of 90, his family has confirmed.
# Summ 2:temperton temperton, one of the uk's most famous 66, has died at the age of 74.
# Summ 3:temperton temperton, a founding member of the magic x factor, has died at the age of 96, his family has said.
# Maynez summaries (factual)
# Summ 0:singer rod temperton, who wrote the hit album michael jackson, has died at the age of 89.
# Summ 1:singer rodton jackson has died at the age of 90, his family has confirmed.
# Summ 2:temperton temperton, one of the uk's most famous 66, has died at the age of 74.
# Summ 3:temperton temperton, a founding member of the magic x factor, has died at the age of 96, his family has said.
#
#
#
# ID: 38159550
# Top1:
# ['An appeal against the conviction of a woman who was found guilty of stealing £1.', 18, {'rouge2': 0.2631578947368421}]
# Correct Summary:
# A woman found guilty of conning a south of Scotland garage firm out of £110,000 has lodged an appeal against her sentence and conviction.
#
# Maynez summaries (non-factual)
# Summ 0:a woman jailed for two years for stealing more than £200, 000 from a dumfries and galloway pensioner has lodged an appeal against her
# Summ 1:a woman who was jailed for three years for conspiring to steal more than £110, 000 from a dumfries castle has had her
# Summ 2:a man who stole more than # 56,000 from a castle in dumfries and galloway has been jailed for six months.
# Summ 3:a woman has been jailed for 12 months for a total of 16 years for money from a court in dumfries and galloway.
# Maynez summaries (factual)
# Summ 0:a woman jailed for two years for stealing more than £200, 000 from a dumfries and galloway pensioner has lodged an appeal against her
# Summ 1:a woman who was jailed for three years for conspiring to steal more than £110, 000 from a dumfries castle has had her
# Summ 2:a man who stole more than # 56,000 from a castle in dumfries and galloway has been jailed for six months.
# Summ 3:a woman has been jailed for 12 months for a total of 16 years for money from a court in dumfries and galloway.
#
#
#
# ID: 39202525
# Top1:
# ['At least 20 people have been killed after a suicide attack on an Afghan hospital in the Afghan capital, Kabul, Afghan officials say.', 27, {'rouge2': 0.37209302325581395}]
# Correct Summary:
# More than 30 people have been killed after attackers dressed as doctors stormed the largest military hospital in Kabul, Afghan officials say.
#
# Maynez summaries (non-factual)
# Summ 0:taliban militants have attacked a hospital in the afghan capital kabul, killing at least 14 people, officials say.
# Summ 1:taliban militants have attacked a hospital in the afghan capital, kabul, killing at least 14 people, officials say.
# Summ 2:a suicide bomber has attacked a hospital in the afghan capital, kabul, killing at least 11 people, officials say.
# Summ 3:at least two people have been killed in a suicide attack on a hospital roof in the afghan capital, afghanistan.
# Maynez summaries (factual)
# Summ 0:taliban militants have attacked a hospital in the afghan capital kabul, killing at least 14 people, officials say.
# Summ 1:taliban militants have attacked a hospital in the afghan capital, kabul, killing at least 14 people, officials say.
# Summ 2:a suicide bomber has attacked a hospital in the afghan capital, kabul, killing at least 11 people, officials say.
# Summ 3:at least two people have been killed in a suicide attack on a hospital roof in the afghan capital, afghanistan.
#
#
#
# ID: 31078095
# Top1:
# ['Russian heptathlete Yuliya Chernova should be banned for life for doping, says former IAAF president Michele Minichiello.', 30, {'rouge2': 0.052631578947368425}]
# Correct Summary:
# Jessica Ennis-Hill's coach Toni Minichiello wants Russian heptathlete Tatyana Chernova's drugs ban to be re-examined by the sporting authorities.
#
# Maynez summaries (non-factual)
# Summ 0:russian sprinter elena chernova should be banned for two years for anabolic sterina chernova's doping use, says the country '
# Summ 1:britain's jessica ennis-hill-hill says she will not compete at the world athletics championships because she faces a doping ban.
# Summ 2:jessica ennis-hill's world champion jessica ennis-hill has been banned for two years for failing a drugs test.
# Summ 3:britain's olympic gold medallist jade chernova has been banned from the world anti-doping agency for failing to qualify for the rio olympics.
# Maynez summaries (factual)
# Summ 0:russian sprinter elena chernova should be banned for two years for anabolic sterina chernova's doping use, says the country '
# Summ 1:britain's jessica ennis-hill-hill says she will not compete at the world athletics championships because she faces a doping ban.
# Summ 2:jessica ennis-hill's world champion jessica ennis-hill has been banned for two years for failing a drugs test.
# Summ 3:britain's olympic gold medallist jade chernova has been banned from the world anti-doping agency for failing to qualify for the rio olympics.
#
#
#
# ID: 37263430
# Top1:
# ["Australia international Aaron Mooy's second-half strike gave Huddersfield maintained their 100% start to the season with victory over Leeds.", 29, {'rouge2': 0.15384615384615385}]
# Correct Summary:
# Aaron Mooy's spectacular long-range strike earned unbeaten Championship leaders Huddersfield Town victory over struggling west Yorkshire rivals Leeds.
#
# Maynez summaries (non-factual)
# Summ 0:huddersfield town moved up to third in the championship table thanks to a second-half strike from josh mooy against leeds united.
# Summ 1:chris mooy's second-half strike gave huddersfield town victory over leeds united.
# Summ 2:leeds maintained their unbeaten start to the season with a hard-fought victory over leeds at elland road.
# Summ 3:leeds united fought back from 2-0 down to beat huddersfield town in the first round of the efl cup.
# Maynez summaries (factual)
# Summ 0:huddersfield town moved up to third in the championship table thanks to a second-half strike from josh mooy against leeds united.
# Summ 1:chris mooy's second-half strike gave huddersfield town victory over leeds united.
# Summ 2:leeds maintained their unbeaten start to the season with a hard-fought victory over leeds at elland road.
# Summ 3:leeds united fought back from 2-0 down to beat huddersfield town in the first round of the efl cup.
#
#
#
# ID: 21326309
# Top1:
# ['Four decommissioned Royal Navy frigates will be put up for sale with bids expected to start in February.', 23, {'rouge2': 0.13636363636363638}]
# Correct Summary:
# More than 20 parties have come forward with bids to either recycle four Royal Navy frigates or turn some of them into artificial reefs, the BBC has learned.
#
# Maynez summaries (non-factual)
# Summ 0:three former royal navy frigates could be put up for sale in the future, the bbc understands.
# Summ 1:plans to build a new generation of royal navy frigates on the isle of wight have been submitted to the government.
# Summ 2:one of the uk's biggest commercial ships has been given the go-ahead by the ministry of defence (mod).
# Summ 3:bids for a new royal navy aircraft have been submitted to the public for the first time in the uk.
# Maynez summaries (factual)
# Summ 0:three former royal navy frigates could be put up for sale in the future, the bbc understands.
# Summ 1:plans to build a new generation of royal navy frigates on the isle of wight have been submitted to the government.
# Summ 2:one of the uk's biggest commercial ships has been given the go-ahead by the ministry of defence (mod).
# Summ 3:bids for a new royal navy aircraft have been submitted to the public for the first time in the uk.
#
#
#
# ID: 37728276
# Top1:
# ['Seahorses have been disappearing from Bristol Bay in recent years.', 14, {'rouge2': 0.08}]
# Correct Summary:
# Spiny seahorses may soon be locally extinct at Studland Bay in Dorset, according to the Seahorse Trust.
#
# Maynez summaries (non-factual)
# Summ 0:an investigation is under way to find out why a seahorse was spotted on the dorset coast.
# Summ 1:a girl has been spotted on a yacht in the north sea, according to a new study.
# Summ 2:a updated bay has been spotted at a beach in south south england.
# Summ 3:a new study has been discovered at a nature reserve in norfolk, where a new study has been found.
# Maynez summaries (factual)
# Summ 0:an investigation is under way to find out why a seahorse was spotted on the dorset coast.
# Summ 1:a girl has been spotted on a yacht in the north sea, according to a new study.
# Summ 2:a updated bay has been spotted at a beach in south south england.
# Summ 3:a new study has been discovered at a nature reserve in norfolk, where a new study has been found.
#
#
#
# ID: 32201626
# Top1:
# ['It was once a bustling town that was the centre of the Irish economy.', 16, {'rouge2': 0.18749999999999997}]
# Correct Summary:
# At one end of the main thoroughfare in the centre of Longford town is the shopping centre that never opened.
#
# Maynez summaries (non-factual)
# Summ 0:the republic of ireland's historic town and business centre may be one of the country's great landmarks.
# Summ 1:the republic of ireland's political parties have been making headlines in the new year.
# Summ 2:the town of glass, a small town in the republic of ireland, is a small town in the republic of ireland.
# Summ 3:it is the word of the longford town of longford town, but it is not enough to know about the future of the longford town.
# Maynez summaries (factual)
# Summ 0:the republic of ireland's historic town and business centre may be one of the country's great landmarks.
# Summ 1:the republic of ireland's political parties have been making headlines in the new year.
# Summ 2:the town of glass, a small town in the republic of ireland, is a small town in the republic of ireland.
# Summ 3:it is the word of the longford town of longford town, but it is not enough to know about the future of the longford town.
#
#
#
# ID: 39540625
# Top1:
# ["Derek McInnes' time at Aberdeen has been hailed by former Dons defender Lee Thompson.", 21, {'rouge2': 0.14285714285714288}]
# Correct Summary:
# Derek McInnes deserves more praise for his achievements at Aberdeen, says ex-Scotland striker Steven Thompson.
#
# Maynez summaries (non-factual)
# Summ 0:aberdeen captain stephen thompson says the club's " great achievement " at the top of the premiership is not the best he has ever been.
# Summ 1:derek mcinnes believes rangers can win the scottish cup again this season.
# Summ 2:aberdeen manager stephen thompson is confident his side can win the scottish cup final this season.
# Summ 3:aberdeen manager lee thompson says derek ``deserve enormous credit for the club''after his side reached the last eight of the scottish premiership.
# Maynez summaries (factual)
# Summ 0:aberdeen captain stephen thompson says the club's " great achievement " at the top of the premiership is not the best he has ever been.
# Summ 1:derek mcinnes believes rangers can win the scottish cup again this season.
# Summ 2:aberdeen manager stephen thompson is confident his side can win the scottish cup final this season.
# Summ 3:aberdeen manager lee thompson says derek ``deserve enormous credit for the club''after his side reached the last eight of the scottish premiership.
#
#
#
# ID: 37480920
# Top1:
# ["A Japanese DJ's bizarre song about a pen and a pineapple has gone viral in Japan, with more than 44m views on Facebook in just over a week.", 33, {'rouge2': 0.0}]
# Correct Summary:
# You are about to witness viral history in the making and none of it will make any sense to you.
#
# Maynez summaries (non-factual)
# Summ 0:it's one of the most popular song in japanese-but a song that has gone viral on social media has become an internet hit.
# Summ 1:there's been a mixed reaction to the latest stage in a live live live action film in japan.
# Summ 2:you have ever seen anything like a pen with a pen or a pineapple, you can not afford to be a dj.
# Maynez summaries (factual)
# Summ 0:it's one of the most popular song in japanese-but a song that has gone viral on social media has become an internet hit.
# Summ 1:there's been a mixed reaction to the latest stage in a live live live action film in japan.
# Summ 2:you have ever seen anything like a pen with a pen or a pineapple, you can not afford to be a dj.
#
#
#
# ID: 28360838
# Top1:
# ['Bolivia has signed a law allowing children under the age of 15 to work for free in private companies, in defiance of international law.', 29, {'rouge2': 0.15999999999999998}]
# Correct Summary:
# Bolivia has lowered the legal working age to allow children to work from the age of 10 as long as they also attend school and are self-employed.
#
# Maynez summaries (non-factual)
# Summ 0:bolivia's parliament has approved a law banning child labour in the country's capital, la paz.
# Summ 1:bolivia's president evo morales has signed a law requiring children to be banned from work in the country.
# Summ 2:bolivian president evo morales has signed a law banning children's rights in latin america.
# Summ 3:bolivia's president evo morales has signed a new law banning children from children under the age of 15.
# Maynez summaries (factual)
# Summ 0:bolivia's parliament has approved a law banning child labour in the country's capital, la paz.
# Summ 1:bolivia's president evo morales has signed a law requiring children to be banned from work in the country.
# Summ 2:bolivian president evo morales has signed a law banning children's rights in latin america.
# Summ 3:bolivia's president evo morales has signed a new law banning children from children under the age of 15.
#
#
#
# ID: 38618826
# Top1:
# ["England's Scott Waites has been knocked out of the BDO World Squash Championship by world number five Jens Noppert in the semi-finals.", 33, {'rouge2': 0.2553191489361702}]
# Correct Summary:
# Defending champion Scott Waites was knocked out of the BDO World Darts Championships as Danny Noppert beat him 5-3 in a dramatic quarter-final.
#
# Maynez summaries (non-factual)
# Summ 0:world number one chris noppert will face dutch qualifier jimmy noppert in the semi-finals of the bdo world championships.
# Summ 1:defending champion glen durrant is through to the semi-finals of the bdo world championships after beating defending champion glen glen durrant.
# Summ 2:england's laura massaro is through to the semi-finals of the women's world squash championship in south korea.
# Summ 3:britain's laura noppert and lauren noppert have been ruled out of the women's doubles in rio on saturday.
# Maynez summaries (factual)
# Summ 0:world number one chris noppert will face dutch qualifier jimmy noppert in the semi-finals of the bdo world championships.
# Summ 1:defending champion glen durrant is through to the semi-finals of the bdo world championships after beating defending champion glen glen durrant.
# Summ 2:england's laura massaro is through to the semi-finals of the women's world squash championship in south korea.
# Summ 3:britain's laura noppert and lauren noppert have been ruled out of the women's doubles in rio on saturday.

# %%
obj['sample'][0]
# Out:
# ["As David Cameron prepares for the first Commons vote on the UK's membership of the European Union, what do its MPs think about the issue?",
#  30,
#  {'rouge2': 0.07692307692307691}]

# %%
a  = df.loc[df.bbcid==int('39979364')]
b = a.loc[a['is_factual'].str.contains("no")]
b
# Out:
#          bbcid   system                                            summary  \
# 60    39979364  BERTS2S  the london 2012 para-athletics world champions...
# 61    39979364  BERTS2S  the london 2012 para-athletics world champions...
# 62    39979364  BERTS2S  the london 2012 para-athletics world champions...
# 4291  39979364    PtGen  the world para athletics championships are tak...
# 4292  39979364    PtGen  the world para athletics championships are tak...
# 4293  39979364    PtGen  the world para athletics championships are tak...
#
#      is_factual worker_id                                                doc  \
# 60           no     wid_0  Symbols of every event feature on the design, ...
# 61           no     wid_1  Symbols of every event feature on the design, ...
# 62           no     wid_2  Symbols of every event feature on the design, ...
# 4291         no     wid_0  Symbols of every event feature on the design, ...
# 4292         no     wid_1  Symbols of every event feature on the design, ...
# 4293         no     wid_2  Symbols of every event feature on the design, ...
#
#                                                    corr  dataind
# 60    The World Championships medals that will be wo...     3603
# 61    The World Championships medals that will be wo...     3603
# 62    The World Championships medals that will be wo...     3603
# 4291  The World Championships medals that will be wo...     3603
# 4292  The World Championships medals that will be wo...     3603
# 4293  The World Championships medals that will be wo...     3603
